# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# %%
customers = pd.read_csv(r"E:\Datasets\Zeotap Task\Customers.csv")
customers['SignupDate'] = pd.to_datetime(customers['SignupDate'])
products = pd.read_csv(r"E:\Datasets\Zeotap Task\Products.csv")
transactions = pd.read_csv(r"E:\Datasets\Zeotap Task\Transactions.csv")
transactions['TransactionDate'] = pd.to_datetime(transactions['TransactionDate'])

merged_data = transactions.merge(customers, on='CustomerID').merge(products.drop('Price',axis=1), on='ProductID')

# %%
latest_date = transactions['TransactionDate'].max()
customers['Tenure'] = (latest_date - customers['SignupDate']).dt.days
customers_encoded = pd.get_dummies(customers, columns=['Region'])
customer_features = customers_encoded[['CustomerID', 'Tenure'] + 
                                      list(customers_encoded.filter(like='Region_'))]

# %%
customer_features
# Out:
#     CustomerID  Tenure  Region_Asia  Region_Europe  Region_North America  \
# 0        C0001     902        False          False                 False
# 1        C0002    1049         True          False                 False
# 2        C0003     296        False          False                 False
# 3        C0004     811        False          False                 False
# 4        C0005     866         True          False                 False
# ..         ...     ...          ...            ...                   ...
# 195      C0196     935        False           True                 False
# 196      C0197     648        False           True                 False
# 197      C0198    1035        False           True                 False
# 198      C0199     756        False           True                 False
# 199      C0200     566         True          False                 False
#
#      Region_South America
# 0                    True
# 1                   False
# 2                    True
# 3                    True
# 4                   False
# ..                    ...
# 195                 False
# 196                 False
# 197                 False
# 198                 False
# 199                 False
#
# [200 rows x 6 columns]

# %%
trans_products = pd.merge(transactions, products, on='ProductID', how='left')
category_dummies = pd.get_dummies(trans_products['Category'], prefix='Category')
trans_products = pd.concat([trans_products['CustomerID'], category_dummies], axis=1)
category_counts = trans_products.groupby('CustomerID').sum().reset_index()

# %%
category_counts
# Out:
#     CustomerID  Category_Books  Category_Clothing  Category_Electronics  \
# 0        C0001               1                  0                     3
# 1        C0002               0                  2                     0
# 2        C0003               0                  1                     1
# 3        C0004               3                  0                     2
# 4        C0005               0                  0                     2
# ..         ...             ...                ...                   ...
# 194      C0196               1                  1                     0
# 195      C0197               0                  0                     2
# 196      C0198               0                  1                     1
# 197      C0199               0                  0                     2
# 198      C0200               1                  2                     1
#
#      Category_Home Decor
# 0                      1
# 1                      2
# 2                      2
# 3                      3
# 4                      1
# ..                   ...
# 194                    2
# 195                    1
# 196                    0
# 197                    2
# 198                    1
#
# [199 rows x 5 columns]

# %%
customer_trans = merged_data.groupby('CustomerID').agg(
    total_transactions=('TransactionID', 'count'),
    total_quantity=('Quantity', 'sum'),
    total_spent=('TotalValue', 'sum'),
    avg_price=('Price', 'mean'),
    last_transaction_date=('TransactionDate', 'max')
).reset_index()


customer_trans['recency'] = (latest_date - customer_trans['last_transaction_date']).dt.days
customer_trans.drop('last_transaction_date', axis=1, inplace=True)
customer_trans = pd.merge(customer_trans, category_counts, on='CustomerID', how='left')

# %%
customer_trans
# Out:
#     CustomerID  total_transactions  total_quantity  total_spent   avg_price  \
# 0        C0001                   5              12      3354.52  278.334000
# 1        C0002                   4              10      1862.74  208.920000
# 2        C0003                   4              14      2725.38  195.707500
# 3        C0004                   8              23      5354.88  240.636250
# 4        C0005                   3               7      2034.24  291.603333
# ..         ...                 ...             ...          ...         ...
# 194      C0196                   4              12      4982.88  416.992500
# 195      C0197                   3               9      1928.65  227.056667
# 196      C0198                   2               3       931.83  239.705000
# 197      C0199                   4               9      1979.28  250.610000
# 198      C0200                   5              16      4758.60  296.506000
#
#      recency  Category_Books  Category_Clothing  Category_Electronics  \
# 0         55               1                  0                     3
# 1         25               0                  2                     0
# 2        125               0                  1                     1
# 3          4               3                  0                     2
# 4         54               0                  0                     2
# ..       ...             ...                ...                   ...
# 194       13               1                  1                     0
# 195        0               0                  0                     2
# 196       84               0                  1                     1
# 197       63               0                  0                     2
# 198       17               1                  2                     1
#
#      Category_Home Decor
# 0                      1
# 1                      2
# 2                      2
# 3                      3
# 4                      1
# ..                   ...
# 194                    2
# 195                    1
# 196                    0
# 197                    2
# 198                    1
#
# [199 rows x 10 columns]

# %%
combined_features = pd.merge(customer_features, customer_trans, on='CustomerID', how='left').fillna(0)

# %%
scaler = StandardScaler()
feature_cols = combined_features.columns.difference(['CustomerID'])
scaled_features = scaler.fit_transform(combined_features[feature_cols])
scaled_df = pd.DataFrame(scaled_features, columns=feature_cols)
scaled_df['CustomerID'] = combined_features['CustomerID']

# %%
scaled_df
# Out:
#      Category_Books  Category_Clothing  Category_Electronics  \
# 0         -0.314627          -1.036192              1.555406
# 1         -1.213560           0.781689             -1.141830
# 2         -1.213560          -0.127252             -0.242751
# 3          1.483240          -1.036192              0.656327
# 4         -1.213560          -1.036192              0.656327
# ..              ...                ...                   ...
# 195       -0.314627          -0.127252             -1.141830
# 196       -1.213560          -1.036192              0.656327
# 197       -1.213560          -0.127252             -0.242751
# 198       -1.213560          -1.036192              0.656327
# 199       -0.314627           0.781689             -0.242751
#
#      Category_Home Decor  Region_Asia  Region_Europe  Region_North America  \
# 0              -0.215318    -0.538816      -0.577350             -0.546536
# 1               0.681841     1.855921      -0.577350             -0.546536
# 2               0.681841    -0.538816      -0.577350             -0.546536
# 3               1.578999    -0.538816      -0.577350             -0.546536
# 4              -0.215318     1.855921      -0.577350             -0.546536
# ..                   ...          ...            ...                   ...
# 195             0.681841    -0.538816       1.732051             -0.546536
# 196            -0.215318    -0.538816       1.732051             -0.546536
# 197            -1.112477    -0.538816       1.732051             -0.546536
# 198             0.681841    -0.538816       1.732051             -0.546536
# 199            -0.215318     1.855921      -0.577350             -0.546536
#
#      Region_South America    Tenure  avg_price   recency  total_quantity  \
# 0                1.545908  1.152884   0.110366 -0.261657       -0.110735
# 1               -0.646869  1.605593  -0.854626 -0.685506       -0.434049
# 2                1.545908 -0.713387  -1.038306  0.727326        0.212579
# 3                1.545908  0.872636  -0.413708 -0.982201        1.667493
# 4               -0.646869  1.042017   0.294836 -0.275785       -0.919021
# ..                    ...       ...        ...       ...             ...
# 195             -0.646869  1.254513   2.037994 -0.855046       -0.110735
# 196             -0.646869  0.370652  -0.602491 -1.038714       -0.595706
# 197             -0.646869  1.562478  -0.426654  0.148065       -1.565649
# 198             -0.646869  0.703255  -0.275053 -0.148630       -0.595706
# 199             -0.646869  0.118120   0.362993 -0.798533        0.535893
#
#      total_spent  total_transactions CustomerID
# 0      -0.051884            0.000000      C0001
# 1      -0.862714           -0.451294      C0002
# 2      -0.393842           -0.451294      C0003
# 3       1.035375            1.353881      C0004
# 4      -0.769499           -0.902587      C0005
# ..           ...                 ...        ...
# 195     0.833181           -0.451294      C0196
# 196    -0.826890           -0.902587      C0197
# 197    -1.368694           -1.353881      C0198
# 198    -0.799371           -0.451294      C0199
# 199     0.711278            0.000000      C0200
#
# [200 rows x 15 columns]

# %%
features_matrix = scaled_df.drop('CustomerID', axis=1).values
features_matrix.shape
# Out:
# (200, 14)

# %%
similarity_matrix = cosine_similarity(features_matrix)

# %%
similarity_matrix.shape
# Out:
# (200, 200)

# %%
similarity_df = pd.DataFrame(similarity_matrix, index=scaled_df['CustomerID'], 
                             columns=scaled_df['CustomerID'])

# %%
similarity_df
# Out:
# CustomerID     C0001     C0002     C0003     C0004     C0005     C0006  \
# CustomerID
# C0001       1.000000 -0.160357  0.267836  0.466293  0.270910  0.132691
# C0002      -0.160357  1.000000  0.043325 -0.229196  0.607333 -0.302448
# C0003       0.267836  0.043325  1.000000  0.085468 -0.086537  0.328843
# C0004       0.466293 -0.229196  0.085468  1.000000 -0.327643  0.183897
# C0005       0.270910  0.607333 -0.086537 -0.327643  1.000000 -0.331802
# ...              ...       ...       ...       ...       ...       ...
# C0196      -0.117568  0.087457 -0.397271 -0.017280  0.028663  0.121957
# C0197       0.197966  0.143039  0.010982 -0.263584  0.394333 -0.414603
# C0198       0.080898  0.337392 -0.033306 -0.579483  0.425473 -0.254899
# C0199       0.209774  0.154781  0.066580 -0.174141  0.377619 -0.463743
# C0200      -0.279308  0.543987 -0.324028 -0.071585  0.386211 -0.140147
#
# CustomerID     C0007     C0008     C0009     C0010  ...     C0191     C0192  \
# CustomerID                                          ...
# C0001       0.255616 -0.060440 -0.173456 -0.354824  ...  0.500640  0.680746
# C0002       0.462176 -0.121776  0.161946  0.353797  ... -0.530905 -0.077291
# C0003      -0.114489 -0.031556 -0.043463 -0.028093  ...  0.063561  0.368126
# C0004      -0.349653  0.435091 -0.778297 -0.401999  ...  0.354949 -0.109473
# C0005       0.924108 -0.332473  0.236475 -0.128256  ... -0.149189  0.231687
# ...              ...       ...       ...       ...  ...       ...       ...
# C0196       0.124678 -0.188530  0.299804  0.130914  ... -0.296588 -0.228453
# C0197       0.213341 -0.218829  0.634467  0.421392  ... -0.064295  0.036752
# C0198       0.359890 -0.565738  0.848696  0.640119  ... -0.218880  0.383976
# C0199       0.302068 -0.084247  0.555703  0.276627  ... -0.273951  0.053259
# C0200       0.344117 -0.004486 -0.183894 -0.022491  ... -0.275188 -0.377839
#
# CustomerID     C0193     C0194     C0195     C0196     C0197     C0198  \
# CustomerID
# C0001      -0.199890 -0.206179  0.068049 -0.117568  0.197966  0.080898
# C0002       0.089756 -0.413741  0.001195  0.087457  0.143039  0.337392
# C0003      -0.264856 -0.169344  0.718734 -0.397271  0.010982 -0.033306
# C0004      -0.116029  0.211769  0.347158 -0.017280 -0.263584 -0.579483
# C0005       0.208258 -0.411090 -0.349599  0.028663  0.394333  0.425473
# ...              ...       ...       ...       ...       ...       ...
# C0196      -0.165338 -0.372804 -0.164469  1.000000  0.300070  0.315161
# C0197      -0.336772 -0.310580 -0.178196  0.300070  1.000000  0.756278
# C0198      -0.001459 -0.558794 -0.440974  0.315161  0.756278  1.000000
# C0199      -0.303914 -0.265961 -0.138613  0.387496  0.899245  0.710274
# C0200       0.139127 -0.239171  0.006923  0.099525 -0.244656 -0.251181
#
# CustomerID     C0199     C0200
# CustomerID
# C0001       0.209774 -0.279308
# C0002       0.154781  0.543987
# C0003       0.066580 -0.324028
# C0004      -0.174141 -0.071585
# C0005       0.377619  0.386211
# ...              ...       ...
# C0196       0.387496  0.099525
# C0197       0.899245 -0.244656
# C0198       0.710274 -0.251181
# C0199       1.000000 -0.351402
# C0200      -0.351402  1.000000
#
# [200 rows x 200 columns]

# %%
target_customers = scaled_df['CustomerID'].head(20).values
lookalike_data = []

for target in target_customers:
    sim_scores = similarity_df.loc[target].drop(target).sort_values(ascending=False)[:3]
    row = [target]
    for cust_id, score in sim_scores.items():
        row.extend([cust_id, round(score, 4)])
    lookalike_data.append(row)


lookalike_df = pd.DataFrame(lookalike_data, columns=['CustomerID', 'Lookalike1', 'Score1', 
                                                    'Lookalike2', 'Score2', 'Lookalike3', 'Score3'])

# %%
lookalike_df
# Out:
#    CustomerID Lookalike1  Score1 Lookalike2  Score2 Lookalike3  Score3
# 0       C0001      C0120  0.7830      C0118  0.7828      C0096  0.7120
# 1       C0002      C0159  0.9332      C0134  0.9192      C0106  0.9190
# 2       C0003      C0031  0.8339      C0129  0.7994      C0052  0.7682
# 3       C0004      C0113  0.9383      C0104  0.8277      C0012  0.7758
# 4       C0005      C0007  0.9241      C0140  0.9029      C0186  0.8373
# 5       C0006      C0187  0.8904      C0137  0.7430      C0085  0.7118
# 6       C0007      C0005  0.9241      C0140  0.8304      C0186  0.7862
# 7       C0008      C0059  0.8013      C0098  0.7953      C0194  0.7817
# 8       C0009      C0061  0.8633      C0198  0.8487      C0167  0.7903
# 9       C0010      C0061  0.7656      C0062  0.7306      C0132  0.7158
# 10      C0011      C0126  0.8563      C0174  0.8428      C0171  0.8376
# 11      C0012      C0004  0.7758      C0163  0.7700      C0065  0.7532
# 12      C0013      C0099  0.7660      C0087  0.7532      C0102  0.7460
# 13      C0014      C0110  0.8187      C0097  0.8141      C0073  0.7932
# 14      C0015      C0185  0.8641      C0058  0.7822      C0036  0.7732
# 15      C0016      C0183  0.9102      C0050  0.8065      C0067  0.7800
# 16      C0017      C0075  0.9425      C0041  0.9278      C0057  0.8243
# 17      C0018      C0117  0.7822      C0055  0.7601      C0194  0.7552
# 18      C0019      C0070  0.8408      C0064  0.7879      C0023  0.6868
# 19      C0020      C0058  0.9477      C0144  0.8387      C0110  0.7795

# %%
lookalike_df.to_csv('Ajayraj_SinghRathore_Lookalike.csv', index=False)
